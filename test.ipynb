# %%
from client.serving_client import *
from client.game_client import *

import requests

# %%
gl = GameClient("localhost","7777")

# %%
gl.serving_client.download_registry_model(model='lr-distance', workspace= "duyhung2201")
# Out:
# "Model downloaded and loaded"
# 'Model downloaded and loaded'

# %%
game_id='2019020411'

# %%
gl.serving_client.model
# Out:
# 'lr-shot-distance'

# %%
df, updated_events, metadata = gl.ping_game(game_id)

# %%
df.shape, updated_events.shape
# Out:
# ((58, 26), (0, 0))

# %%
df
# Out:
#        game_id  event_id         event  period period_time  game_seconds  \
# 0   2019020411        54  shot-on-goal       1       00:50            50
# 1   2019020411        57  shot-on-goal       1       02:07           127
# 2   2019020411        59  shot-on-goal       1       04:23           263
# 3   2019020411        62  shot-on-goal       1       05:14           314
# 4   2019020411        67  shot-on-goal       1       06:21           381
# 5   2019020411        70  shot-on-goal       1       06:54           414
# 6   2019020411        71  shot-on-goal       1       06:56           416
# 7   2019020411        72  shot-on-goal       1       07:01           421
# 8   2019020411        82  shot-on-goal       1       07:02           422
# 9   2019020411        74  shot-on-goal       1       07:35           455
# 10  2019020411        76          goal       1       07:52           472
# 11  2019020411        78  shot-on-goal       1       08:23           503
# ...

# %%
metadata
# Out:
# {'homeTeam': {'id': 19,
#   'name': {'default': 'Blues'},
#   'abbrev': 'STL',
#   'score': 5,
#   'sog': 27,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/STL_light.svg',
#   'placeName': {'default': 'St. Louis'}},
#  'awayTeam': {'id': 5,
#   'name': {'default': 'Penguins'},
#   'abbrev': 'PIT',
#   'score': 2,
#   'sog': 31,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/PIT_light.svg',
#   'placeName': {'default': 'Pittsburgh'}},
#  'id': 2019020411}
